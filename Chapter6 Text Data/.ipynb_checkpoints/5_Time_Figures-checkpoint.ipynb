# %% [markdown]
# # 《时代周刊》年度人物来自的领域的词云图

# %%
from pyecharts.charts import WordCloud   # 导入画词云图需要的库
import pyecharts.options as opts
import pandas as pd

# 读取数据文件
post_data = pd.read_csv('Person of the Year.csv')

## 通过链式调用对数据进行处理：
# grouby：进行分组操作，by=['category']表示按种类进行分组；
# agg：aggregate，对列进行操作的函数，agg({'views': sum})是将每组中的浏览量相加求和
# reset_index()：重置索引（因为按种类分组后之前的索引就不能用了）
post_data2 = post_data.groupby(by=['Category']).agg({'Count': sum}).reset_index()

# 通过for循环将数据转化为二维列表
data = [list(e) for e in zip(post_data2['Category'], 
                             [str(e) for e in post_data2['Count']]
                            )
       ]

# 绘制词云图
wordcloud = WordCloud()
wordcloud.add(series_name = '', # 系列名称
              data_pair = data, # 词和词频组成的数据对，二维列表的格式
              word_size_range = [20, 100], # 设置词云字体大小的区间
              shape = 'cursive', # 词云图的轮廓
              mask_image='Times.png',
              word_gap = 15, # 单词间隔
              #rotate_step = 45, # 旋转单词角度
             )

wordcloud.render_notebook()
# Out:
# D:\Anaconda3-5.3.0\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="e603db294666440b80e21460ee4b7c90" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_e603db294666440b80e21460ee4b7c90 = echarts.init(
#                     document.getElementById('e603db294666440b80e21460ee4b7c90'), 'white', {renderer: 'canvas'});
#
#         var maskImage_e859a105ea954aefa10b9e0d8dc68097 = new Image();
#         maskImage_e859a105ea954aefa10b9e0d8dc68097.src = 'data:image/png;base64,...';
#
# ...
