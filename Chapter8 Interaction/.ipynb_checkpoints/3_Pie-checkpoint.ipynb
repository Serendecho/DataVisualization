# %% [markdown]
# # 饼图

# %%
from pyecharts.charts import Pie
import pyecharts.options as opts
import pandas as pd
from pyecharts.globals import ThemeType

# 读取数据
df = pd.read_csv('city_day.csv')
# 获取城市'City'为'Delhi'的'Date', 'AQI_Bucket'两列的数据
data = df.loc[df['City'] == 'Delhi', ['Date', 'AQI_Bucket']]

# 按空气质量等级分组
rank_message = data.groupby(['AQI_Bucket'])
# 对每种空气质量等级进行计数
rank_com = rank_message['AQI_Bucket'].agg(['count'])
# 在原位置重置索引
rank_com.reset_index(inplace=True)
# 将空气等级按计数降序排列
rank_com_last = rank_com.sort_values('count', ascending=False)

x = rank_com_last['AQI_Bucket']
y = rank_com_last['count']

# 创建一个实例
pie = Pie({'theme': ThemeType.ROMA})

input_data  = [list(z) for z in zip(x, y)]
pie.add('Delhi', input_data, radius=['30%', '75%'])

# 数据格式设置为“标签： 百分比”的形式
pie.set_series_opts(label_opts=opts.LabelOpts(formatter='{b}: {d}%')
                   )

# 设置标题和图例格式
pie.set_global_opts(title_opts=opts.TitleOpts(title='2015-2020印度德里空气质量情况',
                                              pos_left='center',
                                             ),
                    legend_opts=opts.LegendOpts(pos_left='right',
                                                pos_top='5%',
                                                orient='vertical',
                                               )
                   )

pie.render_notebook()
# Out:
# D:\Anaconda3-5.3.0\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="d4655611c60c4527a93ac7f4d04a5401" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_d4655611c60c4527a93ac7f4d04a5401 = echarts.init(
#                     document.getElementById('d4655611c60c4527a93ac7f4d04a5401'), 'roma', {renderer: 'canvas'});
#                 var option_d4655611c60c4527a93ac7f4d04a5401 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "Delhi",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Poor",
#                     "value": 542
#                 },
#                 {
#                     "name": "Very Poor",
#                     "value": 520
#                 },
#                 {
#                     "name": "Moderate",
#                     "value": 519
#                 },
#                 {
#                     "name": "Severe",
#                     "value": 239
#                 },
#                 {
#                     "name": "Satisfactory",
#                     "value": 158
#                 },
#                 {
#                     "name": "Good",
#                     "value": 21
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Poor",
#                 "Very Poor",
#                 "Moderate",
#                 "Severe",
#                 "Satisfactory",
#                 "Good"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "right",
#             "top": "5%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "2015-2020\u5370\u5ea6\u5fb7\u91cc\u7a7a\u6c14\u8d28\u91cf\u60c5\u51b5",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d4655611c60c4527a93ac7f4d04a5401.setOption(option_d4655611c60c4527a93ac7f4d04a5401);
#         });
#     </script>
